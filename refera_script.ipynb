-- %% [markdown]
-- # [REFERA]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [REFERA]    Script Date: 20/11/2023 08:23:00 ******/
CREATE DATABASE [REFERA]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'REFERA', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\REFERA.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'REFERA_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\REFERA_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [REFERA] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [REFERA].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [REFERA] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [REFERA] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [REFERA] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [REFERA] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [REFERA] SET ARITHABORT OFF 
GO
ALTER DATABASE [REFERA] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [REFERA] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [REFERA] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [REFERA] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [REFERA] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [REFERA] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [REFERA] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [REFERA] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [REFERA] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [REFERA] SET  ENABLE_BROKER 
GO
ALTER DATABASE [REFERA] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [REFERA] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [REFERA] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [REFERA] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [REFERA] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [REFERA] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [REFERA] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [REFERA] SET RECOVERY FULL 
GO
ALTER DATABASE [REFERA] SET  MULTI_USER 
GO
ALTER DATABASE [REFERA] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [REFERA] SET DB_CHAINING OFF 
GO
ALTER DATABASE [REFERA] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [REFERA] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [REFERA] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [REFERA] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'REFERA', N'ON'
GO
ALTER DATABASE [REFERA] SET QUERY_STORE = ON
GO
ALTER DATABASE [REFERA] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[categorias]

-- %%
USE [REFERA]
GO

-- %%
/****** Object:  Table [dbo].[categorias]    Script Date: 20/11/2023 08:23:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[categorias](
	[CategoriaID] [nvarchar](50) NULL,
	[Categoria] [nvarchar](50) NULL,
	[Departamento] [nvarchar](50) NULL,
	[Descricao] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[clientes]

-- %%
/****** Object:  Table [dbo].[clientes]    Script Date: 20/11/2023 08:23:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[clientes](
	[ClienteID] [nvarchar](50) NULL,
	[Cliente] [nvarchar](50) NULL,
	[NomeContato] [nvarchar](50) NULL,
	[Endereco] [nvarchar](50) NULL,
	[Cidade] [nvarchar](50) NULL,
	[Pais] [nvarchar](50) NULL,
	[PaisCodigo] [nvarchar](50) NULL,
	[Regiao] [nvarchar](50) NULL,
	[CEP] [nvarchar](50) NULL,
	[Latitude] [float] NULL,
	[Longitude] [float] NULL,
	[Fax] [nvarchar](50) NULL,
	[Telefone] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[fatoCabecalho]

-- %%
/****** Object:  Table [dbo].[fatoCabecalho]    Script Date: 20/11/2023 08:23:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[fatoCabecalho](
	[Data] [datetime2](7) NULL,
	[ClienteID] [nvarchar](50) NULL,
	[FuncionarioID] [int] NULL,
	[ValorFrete] [float] NULL,
	[CupomID] [int] NULL,
	[EmpresaFrete] [nvarchar](50) NULL,
	[DataEntrega] [datetime2](7) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FatoDetalhes_DadosModelagem]

-- %%
/****** Object:  Table [dbo].[FatoDetalhes_DadosModelagem]    Script Date: 20/11/2023 08:23:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FatoDetalhes_DadosModelagem](
	[CupomID] [int] NULL,
	[ProdutoID] [nvarchar](50) NULL,
	[Quantidade] [nvarchar](50) NULL,
	[Valor] [float] NULL,
	[Desconto] [nvarchar](50) NULL,
	[Custo] [float] NULL,
	[ValorLiquido] [float] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[funcionarios]

-- %%
/****** Object:  Table [dbo].[funcionarios]    Script Date: 20/11/2023 08:23:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[funcionarios](
	[FuncionarioID] [int] NULL,
	[Extensao] [nvarchar](50) NULL,
	[NomeFuncionario] [nvarchar](50) NULL,
	[Genero] [nvarchar](50) NULL,
	[DataAdmissao] [datetime2](7) NULL,
	[Escritorio] [nvarchar](50) NULL,
	[Supervisor] [nvarchar](50) NULL,
	[Cargo] [nvarchar](50) NULL,
	[SalarioAnual] [int] NULL,
	[MetaVendas] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[produtos]

-- %%
/****** Object:  Table [dbo].[produtos]    Script Date: 20/11/2023 08:23:01 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[produtos](
	[ProdutoID] [nvarchar](50) NULL,
	[CategoriaID] [nvarchar](50) NULL,
	[Produto] [nvarchar](50) NULL,
	[FornecedorID] [nvarchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [REFERA]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [REFERA] SET  READ_WRITE 
GO
